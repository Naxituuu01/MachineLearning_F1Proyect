# %% [markdown]
# # 🏎️ Proyecto de Machine Learning – Fórmula 1
# ## 📌 Fase 1: Business Understanding (CRISP-DM)
#
# ---
#
# ## 🧭 1. Introducción
#
# La **Fórmula 1 (F1)** representa el nivel más alto del automovilismo mundial y constituye uno de los ecosistemas deportivos más avanzados en términos de **ingeniería, tecnología y análisis de datos**. Desde su temporada inaugural en **1950**, el Campeonato Mundial de Fórmula 1 ha evolucionado hacia una disciplina donde el rendimiento no depende únicamente del piloto, sino de una compleja interacción entre **datos, estrategia, diseño técnico y toma de decisiones**.
#
# En la Fórmula 1 moderna, cada carrera genera miles de registros relacionados con resultados, tiempos, posiciones, rendimiento de pilotos y constructores, circuitos y condiciones de competencia. Esta enorme disponibilidad de información convierte a la F1 en un **caso ideal para la aplicación de técnicas de análisis de datos y Machine Learning**.
#
# Este proyecto tiene como objetivo analizar datos históricos de Fórmula 1 y desarrollar modelos predictivos básicos, siguiendo la metodología **CRISP-DM** e implementando una estructura profesional mediante el framework **Kedro**.
#
# ---
#
# ## 🌍 2. Contexto del Negocio
#
# La Fórmula 1 no es únicamente un deporte, sino un **negocio global altamente competitivo**, donde los equipos invierten millones en investigación, desarrollo y análisis de datos para obtener ventajas marginales que pueden definir un campeonato.
#
# Una de las frases más representativas del contexto del negocio es:
#
# > *“Races are won at the track. Championships are won at the factory.”*
# > — Mercedes AMG Petronas (2019)
#
# Esta afirmación resume la importancia del **análisis previo**, la planificación estratégica y el uso intensivo de datos para anticipar escenarios de carrera. En este contexto, el análisis histórico permite:
#
# - Evaluar el impacto de la posición de salida en el resultado final.
# - Medir la influencia de la experiencia de pilotos y constructores.
# - Identificar patrones de rendimiento a largo plazo.
# - Apoyar decisiones estratégicas basadas en evidencia cuantitativa.
#
# ---
#
# ## ❓ 3. Problema de Negocio
#
# A pesar de contar con décadas de datos históricos, el resultado de una carrera de Fórmula 1 sigue siendo altamente incierto. Esto plantea una serie de preguntas relevantes desde una perspectiva analítica y de negocio:
#
# - ¿Qué factores influyen más en el resultado final de una carrera?
# - ¿La experiencia del piloto tiene mayor impacto que la del constructor?
# - ¿Es posible anticipar si un piloto terminará en el podio?
# - ¿Se puede estimar la posición final de un piloto antes de la carrera?
#
# Responder estas preguntas permite **reducir la incertidumbre**, mejorar la planificación estratégica y comprender mejor los factores que determinan el éxito en la Fórmula 1.
#
# ---
#
# ## 🎯 4. Objetivo General
#
# Desarrollar un proyecto profesional de **Machine Learning**, utilizando el framework **Kedro**, que permita analizar datos históricos de Fórmula 1 y construir modelos predictivos básicos orientados al desempeño de pilotos y constructores en las carreras.
#
# ---
#
# ## 🎯 5. Objetivos Específicos
#
# - Analizar datos históricos de Fórmula 1 desde el año 2000 en adelante.
# - Integrar múltiples datasets relacionales de distintas fuentes.
# - Realizar un Análisis Exploratorio de Datos (EDA) exhaustivo.
# - Preparar los datos mediante limpieza, integración y feature engineering.
# - Definir y justificar variables objetivo para problemas de clasificación y regresión.
# - Entrenar modelos baseline interpretables de Machine Learning.
# - Documentar el proceso siguiendo estándares de la industria.
#
# ---
#
# ## 🤖 6. Objetivos de Machine Learning
#
# El proyecto aborda **dos problemas principales de Machine Learning**, alineados con el contexto del negocio:
#
# ### 🔹 Clasificación
# - **Objetivo:** Predecir si un piloto finalizará una carrera en el podio (Top 3).
# - **Variable objetivo:** `is_podium`
# - **Tipo:** Clasificación binaria
# - **Justificación:** El podio representa el máximo logro individual en una carrera y es un indicador clave de desempeño competitivo.
#
# ### 🔹 Regresión
# - **Objetivo:** Predecir la posición final de un piloto en una carrera.
# - **Variable objetivo:** `positionOrder`
# - **Tipo:** Regresión
# - **Justificación:** Permite estimar el rendimiento relativo de pilotos y constructores en cada evento.
#
# ---
#
# ## 📦 7. Descripción del Dataset
#
# Los datos utilizados en este proyecto provienen del dataset:
#
# **Formula 1 World Championship (1950–2020)**
# - **Autor:** Rohan Rao
# - **Plataforma:** Kaggle
# - **URL:** https://www.kaggle.com/datasets/rohanrao/formula-1-world-championship-1950-2020
#
# Este dataset corresponde a una recopilación histórica oficial de datos de Fórmula 1, **curada y estructurada por Kaggle**, cuyo origen principal es la **Ergast Motor Racing Database**. Es ampliamente utilizado en proyectos académicos y profesionales de análisis deportivo y Machine Learning.
#
# **Características principales:**
# - Cobertura temporal: 1950 – 2020 (con extensiones locales posteriores).
# - Formato: Archivos CSV relacionales.
# - Calidad: Alta consistencia y documentación.
# - Dominio: Resultados oficiales de Fórmula 1.
#
# ---
#
# ## 🧩 8. Datasets Utilizados
#
# En este proyecto se utilizan los siguientes archivos:
#
# - **races.csv:** Información general de cada carrera (año, circuito, fecha).
# - **drivers.csv:** Información de los pilotos.
# - **constructors.csv:** Información de los equipos (constructores).
# - **circuits.csv:** Información de los circuitos.
# - **results.csv:** Resultados detallados por piloto y carrera.
#
# Los datasets se integran mediante claves relacionales como:
# - `raceId`
# - `driverId`
# - `constructorId`
# - `circuitId`
#
# ---
#
# ## 🔍 9. Alcance del Proyecto
#
# ### ✔️ Incluye
# - Integración de múltiples fuentes de datos.
# - Análisis exploratorio univariado, bivariado y multivariado.
# - Limpieza y preparación de datos.
# - Feature engineering basado en experiencia y rendimiento.
# - Modelos baseline de clasificación y regresión.
# - Visualización de resultados y métricas.
#
# ### ❌ No Incluye
# - Telemetría en tiempo real.
# - Simulación avanzada de estrategias de carrera.
# - Optimización compleja de hiperparámetros.
# - Modelos de Deep Learning.
#
# ---
#
# ## 📐 10. Criterios de Éxito
#
# El proyecto será considerado exitoso si:
# - Se ejecuta correctamente mediante `kedro run`.
# - Utiliza al menos tres datasets correctamente integrados.
# - Presenta un EDA completo y bien documentado.
# - Los modelos baseline entregan resultados coherentes.
# - El código es reproducible, limpio y mantenible.
# - La documentación cumple estándares académicos y profesionales.
#
# ---
#
# ## 🗺️ 11. Plan de Trabajo – Metodología CRISP-DM
#
# | Fase | Entregable |
# |-----|-----------|
# | Business Understanding | Notebook 01 |
# | Data Understanding | Notebook 02 |
# | Data Preparation | Notebook 03 |
# | Modeling | Modelos baseline |
# | Evaluation | Métricas y análisis |
# | Deployment | Fuera de alcance |
#
# ---
#
# ## ✅ 12. Cierre de la Fase
#
# Esta fase permitió establecer una comprensión clara del contexto del negocio, los objetivos analíticos y el alcance del proyecto. Con esta base conceptual sólida, el proyecto avanza hacia la fase de **Data Understanding**, donde se explorarán y evaluarán los datos en profundidad para su posterior preparación y modelado.
